# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

df = pd.read_csv("D:\\Users\\Visual\\Downloads\\Python-master\\Python-master\\Arquivo-Treino.csv") #Lendo o conjunto de dados em um dataframe do Pandas
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.describe() #Obter resumo de variáveis numéricas
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
df['Education'].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
df['ApplicantIncome'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='ApplicantIncome')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='ApplicantIncome', by = 'Education')
# Out:
# <AxesSubplot:title={'center':'ApplicantIncome'}, xlabel='Education'>

# %%
df['LoanAmount'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='LoanAmount')
# Out:
# <AxesSubplot:>

# %%
temp1 = df['Credit_History'].value_counts(ascending=True)
temp2 = df.pivot_table(values='Loan_Status',index=['Credit_History'],aggfunc=lambda x: x.map({'Y':1,'N':0}).mean())
print('Tabela de frequência para histórico de crédito:')
print(temp1)
print('\nProbabilidade de obter empréstimo para cada classe de Histórico de Crédito:')
print(temp2)
# Out:
# Tabela de frequência para histórico de crédito:
# 0.0     89
# 1.0    475
# Name: Credit_History, dtype: int64
#
# Probabilidade de obter empréstimo para cada classe de Histórico de Crédito:
#                 Loan_Status
# Credit_History
# 0.0                0.078652
# 1.0                0.795789

# %%
df_tips = sns.load_dataset("penguins")
df_tips.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
#usando seaborn
#
sns.relplot(x="bill_length_mm", y="sex", data=df_tips);

# %%
sns.relplot(x="bill_length_mm", y="bill_depth_mm", hue="sex", data=df_tips);

# %%
sns.relplot(x="bill_length_mm", y="bill_depth_mm", hue="sex", style="species", data=df_tips);
